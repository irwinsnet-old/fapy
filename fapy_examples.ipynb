# %% [markdown]
# ## Imports

# %%
# Imports for telling Python where to find IRScout Python modules
import sys
import os
import re
import base64
import json
sys.path.append('.')

import pandas as pd
import pandas.io.json as pj

import fapy.api as api
import fapy.server as server

username = "sirwin"
key = "1460BE75-DE02-4E4C-AEBF-1C0B58404D5C"

# %%
sn = api.Session(username, key, season='2017')

# %% [markdown]
# ### Status

# %%
status = api.get_status(sn)
status
# Out:
# '{"name":"FIRST ROBOTICS COMPETITION API","version":"2.0","status":"normal"}'

# %%
status.attr

# %% [markdown]
# ### Districts

# %%
dist = api.get_districts(sn)
dist.attr["Last-Modified"]
# Out:
# '{"districts":[{"code":"IN","name":"IndianaFIRST"},{"code":"CHS","name":"FIRST Chesapeake"},{"code":"NC","name":"North Carolina"},{"code":"MAR","name":"Mid-Atlantic Robotics"},{"code":"PCH","name":"Peachtree"},{"code":"ONT","name":"Ontario"},{"code":"PNW","name":"Pacific Northwest"},{"code":"NE","name":"New England"},{"code":"ISR","name":"FIRST Israel"},{"code":"FIM","name":"FIRST In Michigan"}],"districtCount":10}'

# %%
lm = server.httpdate_addsec(dist.attr["Last-Modified"], True)
lm

# %%
dist2 = api.get_districts(sn, mod_since=lm)

# %%
dist2

# %%
dist2["If-Modified-Since"][0]

# %%
dist2.attr

# %%
dist3 = api.get_districts(sn, only_mod_since=lm)
dist3

# %% [markdown]
# ### Seasons

# %%
season = api.get_season(sn)

# %%
season
# Out:
# '{"eventCount":181,"gameName":"FIRST STEAMWORKS","kickoff":"2017-01-07T14:00:00Z","rookieStart":6300,"teamCount":3372,"FRCChampionships":[{"name":"FIRST Championship - Houston","startDate":"2017-04-19T00:00:00","location":"Houston, TX USA"},{"name":"FIRST Championship - St. Louis","startDate":"2017-04-26T00:00:00","location":"St. Louis, MO USA"}]}'

# %%
season.attr

# %%
lms = server.httpdate_addsec(season.attr["Last-Modified"])
lms

# %%
seasons = api.get_season(sn, only_mod_since='Fri, 09 Sep 2017 18:51:07 GMT')

# %%
seasons

# %%
districts = http.getDistricts(sn)
districts

# %%
districts["text"]

# %% [markdown]
# ### Events

# %%
events = api.get_events(sn, district="PNW")
events
# Out:
# '{"Events":[{"code":"ORLAK","divisionCode":null,"name":"PNW District - Lake Oswego Event","type":"DistrictEvent","districtCode":"PNW","venue":"Lake Oswego High School","address":"2501 Country Club Rd","city":"Lake Oswego","stateprov":"OR","country":"USA","website":"http://www.firstwa.org","timezone":"Pacific Standard Time","dateStart":"2017-03-30T00:00:00","dateEnd":"2017-04-01T23:59:59"},{"code":"ORORE","divisionCode":null,"name":"PNW District - Clackamas Academy of Industrial Science Event","type":"DistrictEvent","districtCode":"PNW","venue":"Clackamas Academy","address":"1306 12th Street","city":"Oregon City","stateprov":"OR","country":"USA","website":"http://www.firstwa.org/","timezone":"Pacific Standard Time","dateStart":"2017-03-23T00:00:00","dateEnd":"2017-03-25T23:59:59"},{"code":"ORWIL","divisionCode":null,"name":"PNW District - Wilsonville Event","type":"DistrictEvent","districtCode":"PNW","venue":"Wilsonville High School","address":"6800 SW Wilsonville Road","city":"Wilsonville","stateprov":"OR","country":"USA","website":"http://oregonfirst.org/","timezone":"Pacific Standard Time","dateStart":"2017-03-09T00:00:00","dateEnd":"2017-03-11T23:59:59"},{"code":"PNCMP","divisionCode":null,"name":"Pacific Northwest District Championship","type":"DistrictChampionship","districtCode":"PNW","venue":"Eastern Washington University - Reese Court","address":"526 5th Street","city":"Cheney","stateprov":"WA","country":"USA","website":"http://www.firstwa.org","timezone":"Pacific Standard Time","dateStart":"2017-04-05T00:00:00","dateEnd":"2017-04-08T23:59:59"},{"code":"WAAHS","divisionCode":null,"name":"PNW District - Auburn Event","type":"DistrictEvent","districtCode":"PNW","venue":"Auburn High School","address":"711 E. Main St.","city":"Auburn","stateprov":"WA","country":"USA","website":"http://www.firstwa.org","timezone":"Pacific Standard Time","dateStart":"2017-03-31T00:00:00","dateEnd":"2017-04-02T23:59:59"},{"code":"WAAMV","divisionCode":null,"name":"PNW District - Auburn Mountainview Event","type":"DistrictEvent","districtCode":"PNW","venue":"Auburn Mountainview High School","address":"28900 124th Avenue SE","city":"Auburn","stateprov":"WA","country":"USA","website":"http://www.firstwa.org/","timezone":"Pacific Standard Time","dateStart":"2017-03-03T00:00:00","dateEnd":"2017-03-05T23:59:59"},{"code":"WAELL","divisionCode":null,"name":"PNW District - Central Washington University Event","type":"DistrictEvent","districtCode":"PNW","venue":"Central Washington University - Nicholson Pavilion","address":"715 E. Dean Nicholson Blvd","city":"Ellensburg","stateprov":"WA","country":"USA","website":"http://www.firstwa.org","timezone":"Pacific Standard Time","dateStart":"2017-03-16T00:00:00","dateEnd":"2017-03-18T23:59:59"},{"code":"WAMOU","divisionCode":null,"name":"PNW District - Mount Vernon Event","type":"DistrictEvent","districtCode":"PNW","venue":"Mount Vernon High School","address":"314 North 9th Street","city":"Mount Vernon","stateprov":"WA","country":"USA","website":"http://www.firstwa.org/","timezone":"Pacific Standard Time","dateStart":"2017-03-17T00:00:00","dateEnd":"2017-03-19T23:59:59"},{"code":"WASNO","divisionCode":null,"name":"PNW District - Glacier Peak Event","type":"DistrictEvent","districtCode":"PNW","venue":"Glacier Peak High School","address":"7401 144th Place SE","city":"Snohomish","stateprov":"WA","country":"USA","website":"http://www.firstwa.org/","timezone":"Pacific Standard Time","dateStart":"2017-03-24T00:00:00","dateEnd":"2017-03-26T23:59:59"},{"code":"WASPO","divisionCode":null,"name":"PNW District - West Valley Event","type":"DistrictEvent","districtCode":"PNW","venue":"West Valley High School","address":"8301 E. Buckeye Avenue","city":"Spokane","stateprov":"WA","country":"USA","website":"http://www.firstwa.org","timezone":"Pacific Standard Time","dateStart":"2017-03-02T00:00:00","dateEnd":"2017-03-04T23:59:59"}],"eventCount":10}'

# %%
events.attr["Last-Modified"]

# %%
events2 = api.get_events(sn, district="PNW", only_mod_since=server.httpdate_addsec(events.attr["Last-Modified"]))
events2

# %%
events2.attr

# %%
teams= http.getTeams(sn, district="PNW")
teams

# %%
teams["teamNumber"].iloc[0]

# %% [markdown]
# ### Teams

# %%
teams = api.get_teams(sn, district="PNW", page="1")

# %%
teams
# Out:
#                  city country districtCode homeCMP  \
#                        nameShort                  robotName  rookieYear  \
# 0                 The Revolution       RM 18 (Rainmaker 18)        2000
# 1                      Team XBot                        X17        2000
# 2            Titan Robotics Club                    EsCargo        2001
# 3             Nerds of the North             Quadrivia XVII        2001
# 4             High Desert Droids                     M-cat         2002
# 5                          PHRED                                   2002
# 6   NRG (Newport Robotics Group)              H.P. Lovecube        2002
# 7             Wolverine Robotics                       Fin'        2002
# 8                    CV Robotics                PeaceWalker        2002
# 9                          SWARM            The Killer Wasp        2002
# 10              Spartan Robotics                 Hephaestus        2002
# 11                        SeaBot                   Nautilus        2004
# 12                       Top Gun                   Maverick        2004
# 13     Issaquah Robotics Society                   Cerberus        2004
# 14                     Scalawags            La Dama Vengaza        2004
# 15               Error Code Xero                      Grond        2004
# 16                 Metal Beavers                  Number 12        2004
# 17                      Wildcats                       None        2005
# 18              Flaming Chickens                   Hen Solo        2005
# 19            CALibrate Robotics                       None        2005
# 20                   The Dragons                  Crossfire        2005
# 21                     Chill Out                Snowcrawler        2006
# 22               Saints Robotics                       None        2006
# 23          Skunk Works Robotics                 Ex-Caliper        2007
# 24             Tualatin Robotics                       None        2007
# 25                    Bear Metal                Hindenbearg        2007
# 26                         CHUCK                       None        2007
# 27                  Mechaknights                       None        2007
# 28                   CV Bearbots                 CV Bearbot        2007
# 29                 Crusader Bots        Centaur of Gravitar        2008
# ..                           ...                        ...         ...
# 35                        Skynet                       None        2008
# 36                      RoboRams                       None        2008
# 37                     SOTAbots                      Gemini        2008
# 38            Sehome Seamonsters                       None        2008
# 39                 Lake Monsters                    Trident        2008
# 40                       Pigmice                       None        2009
# 41                     StormBots                StormBot IV        2009
# 42              Flying Hedgehogs                       None        2009
# 43                       NeoBots                  DragonBot        2009
# 44       Sentinel Prime Robotics    Sentinel Prime Robotics        2009
# 45                 Lion Robotics                GWEN d'Lion        2009
# 46               Jack in the Bot                     Jack V        2009
# 47                   Pandamonium                    Cuddles        2009
# 48                        Aggies                 John Deere        2009
# 49                   Robo Sparks                     Sparky        2009
# 50               Viking Robotics                       Odin        2009
# 51                       JAGBOTS                       None        2009
# 52               Sonic Squirrels  Hugo Eekhoorn (/ˈāˌkôrn/)        2009
# 53                      Panda ER              Panda Machine        2009
# 54               Titanium Tigers                  JP Morgan        2009
# 55                    Spartabots                        TBD        2009
# 56  The Whidbey Island Wild Cats   Woodie Flower's Wing Man        2009
# 57                       Hotwire                       None        2009
# 58              My Favorite Team                      Talon        2009
# 59                    BremerTron                       None        2009
# 60                   Team Pronto                Stacy's Mom        2009
# 61                    Gladiators                   Cerberus        2010
# 62              Panther Robotics                    Cyclops        2010
# 63                         TREAD              High Pressure        2010
# 64           Mechanics of Mayhem                       None        2010
#
#                                            schoolName   stateProv  teamNumber  \
# 0                       Bellarmine Preparatory School  Washington         360
# 1               Franklin High School &  xbot robotics  Washington         488
# 2                                International School  Washington         492
# 3   Dimond High School & East High School & Bartle...      Alaska         568
# 4                    Mountain View Senior High School      Oregon         753
# 5                               Philomath High School      Oregon         847
# 6                          Newport Senior High School  Washington         948
# 7                                Bellevue High School  Washington         949
# 18                           http://www.team1540.org/             155
# 19                                http://team1571.org             155
# 20                        http://www.1595dragons.org/             155
# 21                          http://www.first1778.org/             155
# 22                     http://www.saintsrobotics.com/             155
# 23                         http://skunkworks1983.com/             155
# 24                       http://tualatinrobotics.com/             155
# 25                         http://tahomarobotics.org/             155
# 26                                               None             155
# 27                            http://www.Team2148.com             155
# 28                              http://cvhsrobots.com             155
# 29                            http://www.team2374.com             155
# ..                                                ...             ...
# 35                      http://team2550.blogspot.com/             155
# 36                                               None             155
# 37                            http://www.sotabots.com             155
# 38                          www.sehomeseamonsters.org             155
# 39                                    www.frc2635.org             155
# 40                                 www.pigmicepdx.com             155
# 41                           http://www.stormbots.com             155
# 42                http://www.team2898.bpsrobotics.org             155
# 43                            http://neobots2903.org/             155
# 44                                               None             155
# 45                               www.lionrobotics.org             155
# 46                             http://frcteam2910.org             155
# 47                                http://team2915.com             155
# 48                                               None             155
# 49                          http://www.robosparks.com             155
# 50                                 http:/team2928.org             155
# 51                                        jagbots.com             155
# 52                             www.sonicsquirrels.com             155
# 53                                               None             155
# 54                                               None             155
# 55                              http://spartabots.org             155
# 56                  www.team2980.wixsite.com/team2980             155
# 57                         http://hotwirerobotics.com             155
# 58                                       team3024.com             155
# 59                                fluffyrobotics.info             155
# 60                                 team pronto weebly             155
# 61                   http://www.gladstonerobotics.com             155
# 62                        http://pantherrobotics.org/             155
# 63          http://auburnsd.schoolwires.net/Page/1526             155
# 64                                               None             155
#
#     teamCountPage  pageCurrent  pageTotal
# 0              65            1          3
# 1              65            1          3
# 2              65            1          3
# 3              65            1          3
# 4              65            1          3
# 5              65            1          3
# 6              65            1          3
# 7              65            1          3
# 8              65            1          3
# 9              65            1          3
# 10             65            1          3
# 11             65            1          3
# 12             65            1          3
# 13             65            1          3
# 14             65            1          3
# 15             65            1          3
# 16             65            1          3
# 17             65            1          3
# 18             65            1          3
# 19             65            1          3
# 20             65            1          3
# 21             65            1          3
# 22             65            1          3
# 23             65            1          3
# 24             65            1          3
# 25             65            1          3
# 26             65            1          3
# 27             65            1          3
# 28             65            1          3
# 29             65            1          3
# ..            ...          ...        ...
# 35             65            1          3
# 36             65            1          3
# 37             65            1          3
# 38             65            1          3
# 39             65            1          3
# 40             65            1          3
# 41             65            1          3
# 42             65            1          3
# 43             65            1          3
# 44             65            1          3
# 45             65            1          3
# 46             65            1          3
# 47             65            1          3
# 48             65            1          3
# 49             65            1          3
# 50             65            1          3
# 51             65            1          3
# 52             65            1          3
# 53             65            1          3
# 54             65            1          3
# 55             65            1          3
# 56             65            1          3
# 57             65            1          3
# 58             65            1          3
# 59             65            1          3
# 60             65            1          3
# 61             65            1          3
# 62             65            1          3
# 63             65            1          3
# 64             65            1          3
#
# [65 rows x 16 columns]

# %%
teams.index.tea

# %% [markdown]
# ### Schedule

# %%
sched = api.get_schedule(sn, event="TURING", team="1318")

# %%
sched.head(5)

# %% [markdown]
# ### Hybrid

# %%
hybrid = api.get_hybrid(sn, event="TURING")

# %%
hybrid

# %%
hybrid.postResultTime[320]

# %%
hybrid.attr["Last-Modified"]

# %%
hyb2 = api.get_hybrid(sn, event="TURING", only_mod_since="Fri, 21 Apr 2017 13:43:00 GMT")

# %%
hyb2

# %% [markdown]
# ### Matches

# %%
matches = api.get_matches(sn, event="TURING")

# %%
matches.query("teamNumber == 1318")
# Out:
#         dq station  teamNumber  matchNumber        description  \
# 39   False   Blue1        1318            7    Qualification 7
# 113  False   Blue3        1318           19   Qualification 19
# 197  False   Blue3        1318           33   Qualification 33
# 252  False    Red1        1318           43   Qualification 43
# 309  False   Blue1        1318           52   Qualification 52
# 364  False   Blue2        1318           61   Qualification 61
# 430  False   Blue2        1318           72   Qualification 72
# 469  False    Red2        1318           79   Qualification 79
# 596  False    Red3        1318          100  Qualification 100
# 643  False    Red2        1318          108  Qualification 108
#
#     tournamentLevel              actualStartTime               postResultTime  \
# 39    Qualification       2017-04-20T09:40:15.12  2017-04-20T09:42:59.6533333
# 113   Qualification       2017-04-20T11:31:19.42  2017-04-20T11:34:03.4233333
# 197   Qualification  2017-04-20T14:59:29.4766667  2017-04-20T15:02:11.9566667
# 252   Qualification  2017-04-20T16:24:27.4333333       2017-04-20T16:27:30.32
# 309   Qualification  2017-04-21T08:22:40.8366667  2017-04-21T08:25:26.1533333
# 364   Qualification       2017-04-21T09:39:46.58  2017-04-21T09:45:18.5433333
# 430   Qualification       2017-04-21T12:58:01.78       2017-04-21T13:00:49.87
# 469   Qualification  2017-04-21T13:55:57.1466667  2017-04-21T13:59:29.3166667
# 596   Qualification  2017-04-21T16:43:05.0366667  2017-04-21T16:45:49.9933333
# 643   Qualification       2017-04-21T17:49:22.16  2017-04-21T17:52:06.3433333
#
#      scoreRedFinal  scoreRedFoul  scoreRedAuto  scoreBlueFinal  scoreBlueFoul  \
# 39             202             0            70             333              0
# 113            230            25            75             350             25
# 197            290             0            13             345              0
# 252            277             0            17             319             80
# 309            250            25            15             253              0
# 364            311             5            75             322             10
# 430            345             0            75             295              0
# 469            246             0            76             205              0
# 596            307             0            76             282             25
# 643            352             5            76             225              0
#
#      scoreBlueAuto
# 39              23
# 113            135
# 197             75
# 252             19
# 309             15
# 364             82
# 430             75
# 469             75
# 596             77
# 643             15

# %% [markdown]
# ### Scores

# %%
scores = api.get_scores(sn, event="TURING", level="playoff")

# %%
scores
# Out:
#     adjustPoints alliance  autoFuelHigh  autoFuelLow  autoFuelPoints  \
# 0              0     Blue             0            0               0
# 1              0      Red             6            0               6
# 2              0     Blue             0            0               0
# 3              0      Red             0            0               0
# 4              0     Blue             0            0               0
# 5              0      Red            21            0              21
# 6              0     Blue             0            0               0
# 7              0      Red             3            0               3
# 8              0     Blue             0            0               0
# 9              0      Red             5            0               5
# 10             0     Blue             4            0               4
# 11             0      Red             0            0               0
# 12             0     Blue             0            0               0
# 13             0      Red            14            0              14
# 14             0     Blue             0            0               0
# 15             0      Red             9            0               9
# 16             0     Blue            13            0              13
# 17             0      Red             5            0               5
# 18             0     Blue             8            0               8
# 19             0      Red            12            0              12
# 20             0     Blue             0            0               0
# 21             0      Red            14            0              14
# 22             0     Blue             5            0               5
# 23             0      Red            19            0              19
# 24             0     Blue             1            0               1
# 25             0      Red            25            0              25
# 26             0     Blue             9            0               9
# 27             0      Red            22            0              22
# 28             0     Blue             7            0               7
# 29             0      Red            11            0              11
# 30             0     Blue             3            0               3
# 31             0      Red            25            0              25
#
#     autoMobilityPoints  autoPoints  autoRotorPoints  foulCount  foulPoints  \
# 0                   15          75               60          0           0
# 1                   15          81               60          0           0
# 2                   15          75               60          0           0
# 3                   15          15                0          0           0
# 4                   15          75               60          0           0
# 5                   15          96               60          0           0
# 6                   15          75               60          1           5
# 7                   15          78               60          1          30
# 8                   15          75               60          1           0
# 9                   15          80               60          0           5
# 10                  15          79               60          0          25
# 11                  15          75               60          0           0
# 12                  15          75               60          0           0
# 13                  15          89               60          0           0
# 14                  15          75               60          0           0
# 15                  15         144              120          0           0
# 16                  15          88               60          0          25
# 17                  15          80               60          0           0
# 18                  15         143              120          2           0
# 19                  15          87               60          0          10
# 20                  15          15                0          0           0
# 21                  15          89               60          0           0
# 22                  15         140              120          0           0
# 23                  10          89               60          0           0
# 24                  15          16                0          0           0
# 25                  15         100               60          0           0
# 26                  15         144              120          1           0
# 27                  15          97               60          0          30
# 28                  15          82               60          0          30
# 29                  15          86               60          1           0
# 30                  15          78               60          0           0
# 31                  15         100               60          0           0
#
#        ...       teleopFuelPoints  teleopPoints teleopRotorPoints  \
# 0      ...                      2           322               120
# 1      ...                     11           381               120
# 2      ...                      4           374               120
# 3      ...                      2           412               160
# 4      ...                      0           230                80
# 5      ...                     21           411               120
# 6      ...                      0           270               120
# 7      ...                     13           383               120
# 8      ...                      2           322               120
# 9      ...                     11           381               120
# 10     ...                      3           373               120
# 11     ...                      4           374               120
# 12     ...                      0           370               120
# 13     ...                     21           391               120
# 14     ...                      0           180                80
# 15     ...                     10           340                80
# 16     ...                      1           371               120
# 17     ...                     10           280               120
# 18     ...                     12           242                80
# 19     ...                      4           324               120
# 20     ...                      0           410               160
# 21     ...                      5           375               120
# 22     ...                     11           341                80
# 23     ...                     19           149                80
# 24     ...                      0           220               120
# 25     ...                      1           231                80
# 26     ...                     30           360                80
# 27     ...                      5           135                80
# 28     ...                     21           391               120
# 29     ...                      5           185                80
# 30     ...                     13           383               120
# 31     ...                      4           324               120
#
#    teleopTakeoffPoints totalPoints      touchpadFar   touchpadMiddle  \
# 0                  100         397  ReadyForTakeoff             None
# 1                  150         462  ReadyForTakeoff  ReadyForTakeoff
# 2                  150         449  ReadyForTakeoff  ReadyForTakeoff
# 3                  150         427  ReadyForTakeoff  ReadyForTakeoff
# 4                  150         305  ReadyForTakeoff  ReadyForTakeoff
# 5                  150         507  ReadyForTakeoff  ReadyForTakeoff
# 6                   50         350             None  ReadyForTakeoff
# 7                  150         491  ReadyForTakeoff  ReadyForTakeoff
# 8                  100         397             None  ReadyForTakeoff
# 9                  150         466  ReadyForTakeoff  ReadyForTakeoff
# 10                 150         477  ReadyForTakeoff  ReadyForTakeoff
# 11                 150         449  ReadyForTakeoff  ReadyForTakeoff
# 12                 150         445  ReadyForTakeoff  ReadyForTakeoff
# 13                 150         480  ReadyForTakeoff  ReadyForTakeoff
# 14                 100         255             None  ReadyForTakeoff
# 15                 150         484  ReadyForTakeoff  ReadyForTakeoff
# 16                 150         484  ReadyForTakeoff  ReadyForTakeoff
# 17                  50         360  ReadyForTakeoff             None
# 18                  50         385  ReadyForTakeoff             None
# 19                 100         421  ReadyForTakeoff             None
# 20                 150         425  ReadyForTakeoff  ReadyForTakeoff
# 21                 150         464  ReadyForTakeoff  ReadyForTakeoff
# 22                 150         481  ReadyForTakeoff  ReadyForTakeoff
# 23                  50         238             None             None
# 24                 100         236             None  ReadyForTakeoff
# 25                 150         331  ReadyForTakeoff  ReadyForTakeoff
# 26                 150         504  ReadyForTakeoff  ReadyForTakeoff
# 27                  50         262             None  ReadyForTakeoff
# 28                 150         503  ReadyForTakeoff  ReadyForTakeoff
# 29                 100         271  ReadyForTakeoff  ReadyForTakeoff
# 30                 150         461  ReadyForTakeoff  ReadyForTakeoff
# 31                 100         424             None  ReadyForTakeoff
#
#        touchpadNear  matchLevel  matchNumber
# 0   ReadyForTakeoff     Playoff            1
# 1   ReadyForTakeoff     Playoff            1
# 2   ReadyForTakeoff     Playoff            2
# 3   ReadyForTakeoff     Playoff            2
# 4   ReadyForTakeoff     Playoff            3
# 5   ReadyForTakeoff     Playoff            3
# 6              None     Playoff            4
# 7   ReadyForTakeoff     Playoff            4
# 8   ReadyForTakeoff     Playoff            5
# 9   ReadyForTakeoff     Playoff            5
# 10  ReadyForTakeoff     Playoff            6
# 11  ReadyForTakeoff     Playoff            6
# 12  ReadyForTakeoff     Playoff            7
# 13  ReadyForTakeoff     Playoff            7
# 14  ReadyForTakeoff     Playoff            8
# 15  ReadyForTakeoff     Playoff            8
# 16  ReadyForTakeoff     Playoff           13
# 17             None     Playoff           13
# 18             None     Playoff           14
# 19  ReadyForTakeoff     Playoff           14
# 20  ReadyForTakeoff     Playoff           15
# 21  ReadyForTakeoff     Playoff           15
# 22  ReadyForTakeoff     Playoff           16
# 23  ReadyForTakeoff     Playoff           16
# 24  ReadyForTakeoff     Playoff           17
# 25  ReadyForTakeoff     Playoff           17
# 26  ReadyForTakeoff     Playoff           18
# 27             None     Playoff           18
# 28  ReadyForTakeoff     Playoff           19
# 29             None     Playoff           19
# 30  ReadyForTakeoff     Playoff           20
# 31  ReadyForTakeoff     Playoff           20
#
# [32 rows x 36 columns]

# %% [markdown]
# ## Local Data

# %%
snl = fc.Session(auth.username, "key", data_format = "json")

# %%
res_l = get.season(snl)
res_l

# %% [markdown]
# ## Time stuff

# %%
import time
time.tzname

# %% [markdown]
# ## Other Stuff

# %%
import re

# %%
cmd_ptn = r"/v2\.0/\d{4}/(\w+)(?:[/?]|$)"
url = 'https://frc-api.firstinspires.org/v2.0/2017/teams?districtCode=PNW&page=3'
url_season = 'https://frc-api.firstinspires.org/v2.0/2017'
url_status = 'https://frc-api.firstinspires.org/v2.0'
season_ptn = r"/v2\.0/\d{4}$"
status_ptn = r"/v2\.0$"

# %%
mtch = re.search(status_ptn, url_season)

# %%
mtch.group()

# %%
status.attr["url"]

# %%
fi._get_local_data(sn, url)
